# %%
import matplotlib.pyplot as plt
import cv2
from colorizers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-84cb297becb8> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import cv2
# ----> 3 from colorizers import *
#
# ModuleNotFoundError: No module named 'colorizers'

# %%
img = cv2.cvtColor(plt.imread('/Users/kevinyoussef/Desktop/ECE 253/HW1/tesla.jpeg'),cv2.COLOR_RGB2GRAY)

# %%
rgb = plt.imread('/Users/kevinyoussef/Desktop/ECE 253/HW1/tesla.jpeg')
plt.imshow(rgb)

# %%
plt.imshow(img)

# %%
cv2.imwrite('gray.png', img)
# Out:
# True
